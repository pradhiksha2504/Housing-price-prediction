# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv("/content/drive/MyDrive/HousingData.csv")

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90    NaN  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99    NaN  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# DESCRIPTIVE ANANLYSIS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.size
# Out:
# 7084

# %%
df.shape
# Out:
# (506, 14)

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# std     27.999513    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.175000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     76.800000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     93.975000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  486.000000  506.000000
# mean    12.715432   22.532806
# std      7.155871    9.197104
# min      1.730000    5.000000
# 25%      7.125000   17.025000
# 50%     11.430000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 120

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 394 entries, 0 to 504
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     394 non-null    float64
#  1   ZN       394 non-null    float64
#  2   INDUS    394 non-null    float64
#  3   CHAS     394 non-null    float64
#  4   NOX      394 non-null    float64
#  5   RM       394 non-null    float64
#  6   AGE      394 non-null    float64
#  7   DIS      394 non-null    float64
#  8   RAD      394 non-null    int64
#  9   TAX      394 non-null    int64
#  10  PTRATIO  394 non-null    float64
#  11  B        394 non-null    float64
#  12  LSTAT    394 non-null    float64
#  13  MEDV     394 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 46.2 KB

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  394.000000  394.000000  394.000000  394.000000  394.000000  394.000000
# mean     3.690136   11.460660   11.000863    0.068528    0.553215    6.280015
# std      9.202423   23.954082    6.908364    0.252971    0.113112    0.697985
# min      0.006320    0.000000    0.460000    0.000000    0.389000    3.561000
# 25%      0.081955    0.000000    5.130000    0.000000    0.453000    5.879250
# 50%      0.268880    0.000000    8.560000    0.000000    0.538000    6.201500
# 75%      3.435973   12.500000   18.100000    0.000000    0.624000    6.605500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  394.000000  394.000000  394.000000  394.000000  394.000000  394.000000
# mean    68.932741    3.805268    9.403553  406.431472   18.537563  358.490939
# std     27.888705    2.098571    8.633451  168.312419    2.166460   89.283295
# min      2.900000    1.129600    1.000000  187.000000   12.600000    2.600000
# 25%     45.475000    2.110100    4.000000  280.250000   17.400000  376.707500
# 50%     77.700000    3.199200    5.000000  330.000000   19.100000  392.190000
# 75%     94.250000    5.116700   24.000000  666.000000   20.200000  396.900000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  394.000000  394.000000
# mean    12.769112   22.359645
# std      7.308430    9.142979
# min      1.730000    5.000000
# 25%      7.125000   16.800000
# 50%     11.300000   21.050000
# 75%     17.117500   25.000000
# max     37.970000   50.000000

# %%
df.shape
# Out:
# (394, 14)

# %%
df.size
# Out:
# 5516

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 5    0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 499  0.17783   0.0   9.69   0.0  0.585  5.569  73.5  2.3999    6  391
# 500  0.22438   0.0   9.69   0.0  0.585  6.027  79.7  2.4982    6  391
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 5       18.7  394.12   5.21  28.7
# ..       ...     ...    ...   ...
# 499     19.2  395.77  15.10  17.5
# 500     19.2  396.90  14.33  16.8
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
#
# [394 rows x 14 columns]

# %%
plt.subplots(figsize=(13, 10))
sb.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
cat_col = ['CHAS','RAD']
num_col = ['CRIM','ZN','INDUS','NOX','RM','AGE','DIS','TAX','PTRATIO','B','LSTAT']
cols = cat_col + num_col

# %%
cols
# Out:
# ['CHAS',
#  'RAD',
#  'CRIM',
#  'ZN',
#  'INDUS',
#  'NOX',
#  'RM',
#  'AGE',
#  'DIS',
#  'TAX',
#  'PTRATIO',
#  'B',
#  'LSTAT']

# %% [markdown]
# NORMALIZATION

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
y = df['MEDV']
df = df.drop("MEDV", axis=1)

# %%
num_col
# Out:
# ['CRIM',
#  'ZN',
#  'INDUS',
#  'NOX',
#  'RM',
#  'AGE',
#  'DIS',
#  'TAX',
#  'PTRATIO',
#  'B',
#  'LSTAT']

# %%
Scaler = StandardScaler()
scaled_cols = Scaler.fit_transform(df[num_col])

scaled_cols = pd.DataFrame(scaled_cols)
scaled_cols.columns = num_col
scaled_cols.head()
# Out:
#        CRIM        ZN     INDUS       NOX        RM       AGE       DIS  \
# 0 -0.400818  0.273342 -1.259620 -0.134687  0.423161 -0.134014  0.135851
# 1 -0.398535 -0.479051 -0.569724 -0.745475  0.202245  0.357849  0.554334
# 2 -0.398537 -0.479051 -0.569724 -0.745475  1.298216 -0.281214  0.554334
# 3 -0.397984 -0.479051 -1.278462 -0.842847  1.029962 -0.830521  1.076829
# 4 -0.398258 -0.479051 -1.278462 -0.842847  0.215156 -0.367380  1.076829
#
#         TAX   PTRATIO         B     LSTAT
# 0 -0.656944 -1.496303  0.430740 -1.067126
# 1 -0.978184 -0.340879  0.430740 -0.497196
# 2 -0.978184 -0.340879  0.385097 -1.197278
# 3 -1.097162  0.075073  0.405283 -1.346610
# 4 -1.097162  0.075073  0.399564 -1.035615

# %%
scaled_cols.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
scaled_col = Scaler.fit_transform(df[cat_col])

scaled_col = pd.DataFrame(scaled_col)
scaled_col.columns = cat_col
scaled_col.head()
# Out:
#        CHAS       RAD
# 0 -0.271237 -0.974609
# 1 -0.271237 -0.858633
# 2 -0.271237 -0.858633
# 3 -0.271237 -0.742657
# 4 -0.271237 -0.742657

# %%
scaled_col.isnull().sum()
# Out:
# CHAS    0
# RAD     0
# dtype: int64

# %%
df2 = (scaled_col).join(scaled_cols)
df2.head()
# Out:
#        CHAS       RAD      CRIM        ZN     INDUS       NOX        RM  \
# 0 -0.271237 -0.974609 -0.400818  0.273342 -1.259620 -0.134687  0.423161
# 1 -0.271237 -0.858633 -0.398535 -0.479051 -0.569724 -0.745475  0.202245
# 2 -0.271237 -0.858633 -0.398537 -0.479051 -0.569724 -0.745475  1.298216
# 3 -0.271237 -0.742657 -0.397984 -0.479051 -1.278462 -0.842847  1.029962
# 4 -0.271237 -0.742657 -0.398258 -0.479051 -1.278462 -0.842847  0.215156
#
#         AGE       DIS       TAX   PTRATIO         B     LSTAT
# 0 -0.134014  0.135851 -0.656944 -1.496303  0.430740 -1.067126
# 1  0.357849  0.554334 -0.978184 -0.340879  0.430740 -0.497196
# 2 -0.281214  0.554334 -0.978184 -0.340879  0.385097 -1.197278
# 3 -0.830521  1.076829 -1.097162  0.075073  0.405283 -1.346610
# 4 -0.367380  1.076829 -1.097162  0.075073  0.399564 -1.035615

# %%
df2.isnull().sum()
# Out:
# CHAS       0
# RAD        0
# CRIM       0
# ZN         0
# INDUS      0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
(X_train, X_test, y_train, y_test) = train_test_split(df2,y,test_size=0.1)

# %%
y_test.shape
# Out:
# (40,)

# %%
X_test.shape
# Out:
# (40, 13)

# %%
X_train
# Out:
#          CHAS       RAD      CRIM        ZN     INDUS       NOX        RM  \
# 342 -0.271237  1.692835  0.620243 -0.479051  1.028921  1.653416 -0.936762
# 362 -0.271237  1.692835  1.021133 -0.479051  1.028921  0.237096 -0.813393
# 32  -0.271237 -0.510706 -0.382460 -0.479051 -0.730603 -0.479915 -0.450460
# 178 -0.271237 -0.162778 -0.344173 -0.479051 -0.695818 -0.435655  3.507373
# 49  -0.271237 -0.162778 -0.390269  0.565939 -0.850900 -0.887107 -0.506406
# ..        ...       ...       ...       ...       ...       ...       ...
# 22  -0.271237 -0.626681 -0.328399 -0.479051 -0.414642 -0.134687 -0.669941
# 212 -0.271237 -0.742657 -0.389037  0.356941 -0.585667 -0.789735  0.370084
# 172  3.686813 -0.510706 -0.389462 -0.479051  0.418740 -0.028463 -0.471978
# 369 -0.271237  1.692835  1.233118 -0.479051  1.028921  0.538064 -1.400111
# 214  3.686813 -0.626681 -0.395365  1.192933 -0.665382 -0.940219  0.685677
#
#           AGE       DIS       TAX   PTRATIO         B     LSTAT
# 342  0.896385 -0.948548  1.544144  0.768327  0.430740  1.385215
# 362 -0.439185 -0.468326  1.544144  0.768327  0.430740  0.272756
# 32  -1.390598  0.020054 -0.758075  0.306158  0.391826 -0.361564
# 178  0.505048 -0.434594 -0.591507 -0.525747  0.263643 -1.115077
# 49  -0.780258  1.491828 -0.728331  0.537243  0.430740 -0.486236
# ..        ...       ...       ...       ...       ...       ...
# 22   0.767136  0.418307 -0.591507  1.138063  0.206225  0.279606
# 212 -0.367380  0.053548 -1.091213  0.028856  0.408984 -0.690370
# 172  0.892794 -0.437027 -0.775922 -0.987917  0.430740  0.705683
# 369  1.018453 -0.813284  1.544144  0.768327 -0.101054  1.663329
# 214 -1.293662  0.129935 -0.906798 -0.433313  0.430740 -1.265779
#
# [354 rows x 13 columns]

# %%
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(13, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1))

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.0001), loss='mean_squared_error')

# %%
model.fit(X_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 12/12 [==============================] - 3s 8ms/step - loss: 568.8427
# Epoch 2/50
# 12/12 [==============================] - 0s 4ms/step - loss: 552.3391
# Epoch 3/50
# 12/12 [==============================] - 0s 4ms/step - loss: 532.5107
# Epoch 4/50
# 12/12 [==============================] - 0s 8ms/step - loss: 505.6983
# Epoch 5/50
# 12/12 [==============================] - 0s 4ms/step - loss: 465.5945
# Epoch 6/50
# 12/12 [==============================] - 0s 4ms/step - loss: 401.2506
# Epoch 7/50
# 12/12 [==============================] - 0s 3ms/step - loss: 300.8236
# Epoch 8/50
# 12/12 [==============================] - 0s 12ms/step - loss: 192.3999
# Epoch 9/50
# 12/12 [==============================] - 0s 7ms/step - loss: 119.1017
# Epoch 10/50
# 12/12 [==============================] - 0s 8ms/step - loss: 90.2567
# Epoch 11/50
# 12/12 [==============================] - 0s 7ms/step - loss: 75.5389
# Epoch 12/50
# 12/12 [==============================] - 0s 5ms/step - loss: 61.0693
# Epoch 13/50
# 12/12 [==============================] - 0s 6ms/step - loss: 51.3844
# Epoch 14/50
# 12/12 [==============================] - 0s 4ms/step - loss: 43.5137
# Epoch 15/50
# 12/12 [==============================] - 0s 6ms/step - loss: 37.5765
# Epoch 16/50
# 12/12 [==============================] - 0s 4ms/step - loss: 33.6075
# Epoch 17/50
# 12/12 [==============================] - 0s 5ms/step - loss: 29.7185
# Epoch 18/50
# 12/12 [==============================] - 0s 6ms/step - loss: 27.2921
# Epoch 19/50
# 12/12 [==============================] - 0s 6ms/step - loss: 25.8066
# Epoch 20/50
# 12/12 [==============================] - 0s 4ms/step - loss: 24.6900
# Epoch 21/50
# 12/12 [==============================] - 0s 7ms/step - loss: 24.2082
# Epoch 22/50
# 12/12 [==============================] - 0s 5ms/step - loss: 23.6267
# Epoch 23/50
# 12/12 [==============================] - 0s 6ms/step - loss: 22.5927
# Epoch 24/50
# 12/12 [==============================] - 0s 4ms/step - loss: 21.8277
# Epoch 25/50
# 12/12 [==============================] - 0s 4ms/step - loss: 21.1706
# Epoch 26/50
# 12/12 [==============================] - 0s 5ms/step - loss: 20.8641
# Epoch 27/50
# 12/12 [==============================] - 0s 5ms/step - loss: 20.3659
# Epoch 28/50
# 12/12 [==============================] - 0s 3ms/step - loss: 19.8969
# Epoch 29/50
# 12/12 [==============================] - 0s 3ms/step - loss: 19.7491
# Epoch 30/50
# 12/12 [==============================] - 0s 5ms/step - loss: 19.2411
# Epoch 31/50
# 12/12 [==============================] - 0s 3ms/step - loss: 19.0019
# Epoch 32/50
# 12/12 [==============================] - 0s 2ms/step - loss: 18.8987
# Epoch 33/50
# 12/12 [==============================] - 0s 3ms/step - loss: 18.2904
# Epoch 34/50
# 12/12 [==============================] - 0s 2ms/step - loss: 18.5143
# Epoch 35/50
# 12/12 [==============================] - 0s 3ms/step - loss: 17.8476
# Epoch 36/50
# 12/12 [==============================] - 0s 2ms/step - loss: 18.3938
# Epoch 37/50
# 12/12 [==============================] - 0s 3ms/step - loss: 17.2945
# Epoch 38/50
# 12/12 [==============================] - 0s 4ms/step - loss: 17.2111
# Epoch 39/50
# 12/12 [==============================] - 0s 3ms/step - loss: 16.8565
# Epoch 40/50
# 12/12 [==============================] - 0s 3ms/step - loss: 16.7653
# Epoch 41/50
# 12/12 [==============================] - 0s 4ms/step - loss: 16.5729
# Epoch 42/50
# 12/12 [==============================] - 0s 4ms/step - loss: 16.4398
# Epoch 43/50
# 12/12 [==============================] - 0s 4ms/step - loss: 16.2785
# Epoch 44/50
# 12/12 [==============================] - 0s 4ms/step - loss: 16.1565
# Epoch 45/50
# 12/12 [==============================] - 0s 3ms/step - loss: 16.0020
# Epoch 46/50
# 12/12 [==============================] - 0s 3ms/step - loss: 15.8102
# Epoch 47/50
# 12/12 [==============================] - 0s 3ms/step - loss: 15.7182
# Epoch 48/50
# 12/12 [==============================] - 0s 6ms/step - loss: 15.5213
# Epoch 49/50
# 12/12 [==============================] - 0s 3ms/step - loss: 15.4299
# Epoch 50/50
# 12/12 [==============================] - 0s 7ms/step - loss: 15.3239

# %%
from sklearn.metrics import mean_squared_error
# Make predictions on the test set
predictions = model.predict(X_test)

# Calculate the mean squared error
mse = mean_squared_error(y_test, predictions)

print(mse)
# Out:
# 2/2 [==============================] - 0s 5ms/step
# 12.365274099840855

# %%
from sklearn.metrics import mean_squared_error
# Make predictions on the test set
predictions = model.predict(X_test)

# Calculate the mean absolute error
mae = mean_squared_error(y_test, predictions)

print(mae)
# Out:
# 2/2 [==============================] - 0s 5ms/step
# 12.365274099840855
